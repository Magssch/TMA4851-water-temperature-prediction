# %% [markdown]
# ## Setup

# %%
import pandas as pd
from tensorflow import keras as ks
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM, Input, Dense, Dropout, Bidirectional, Conv1D, MaxPooling1D, Flatten, RepeatVector
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, RMSprop, Adagrad
from tensorflow.keras.callbacks import EarlyStopping 
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import ColumnTransformer 
import matplotlib.pyplot as plt
from keras.models import load_model
from keras.metrics import RootMeanSquaredError
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams

# Hack in order to make dictionary entries accessible as attributes (e.g. parameters.parameter)
class AttrDict(dict):
    def __init__(self, *args, **kwargs):
        super(AttrDict, self).__init__(*args, **kwargs)
        self.__dict__ = self

# %matplotlib inline
# %config InlineBackend.figure_format='retina'
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 18, 8
ks.backend.clear_session()

# %% [markdown]
# # Hyperparameter tuning

# %%
# features: "air_temperature", "relative_humidity", "rainfall", "wind_speed", "wind_direction", "tide_obs", "tide_pred", "hour"
hyperparams = AttrDict({
    "num_of_epochs": 300,
    "learning_rate": 0.005,
    "batch_size": 30,
    "loss_function": "mse",
    "earlystopping_patience": 12,
    "look_back": 18,
    "look_back_skip": 2,
    "optimizer": Adagrad,
    "features": ["air_temperature", "hour", "relative_humidity", "windx", "windy"],
})

# %% [markdown]
# ## Dataset and preprocessing

# %%
# read dataset to pandas DataFrame
dataset = pd.read_table(
    #'/kaggle/input/badetemperaturer/badetemperaturer.csv', 
    #'/kaggle/input/korsvika/korsvika_water_air_hum.csv',
    '/kaggle/input/korsvika-multivariate/interpolated_data-duplicates_removed.csv',
    delimiter=",", 
    decimal=".", 
    dtype=np.float64, 
    parse_dates=["time"],
    index_col="time"
)

# For inspiration:
# https://www.tensorflow.org/tutorials/structured_data/time_series#feature_engineering

dataset["timestamp"] = dataset.index.values.astype("int64") / 1e9
dataset["hour"] = np.sin(2*np.pi * dataset["timestamp"]/(24*60*60)) # sine-like signal
dataset["year"] = np.sin(2*np.pi * dataset["timestamp"]/(365*24*60*60))

dataset["month"] = dataset.index.month.values.astype("int64")

# Engineer wind
dataset["windx"] = dataset["wind_speed"] * np.cos(2*np.pi * dataset["wind_direction"]/360)
dataset["windy"] = dataset["wind_speed"] * np.sin(2*np.pi * dataset["wind_direction"]/360)

# Remove indoor winter warnings
#dataset = dataset[:10081]

# Use data from summer season only
dataset = dataset[dataset.index.month.isin([4,5,6,7,8,9,10,11])]

index_between_years = 1
while index_between_years < dataset.shape[0] and dataset.index[index_between_years].year == dataset.index[index_between_years-1].year: 
    index_between_years += 1    
validation_data_non_scaled = dataset[:index_between_years]
training_data_non_scaled = dataset[index_between_years:]

# Skip every 2nd row to match weather API and use every 2nd row for validation data
#training_data = dataset2020.iloc[::2, :]
#validation_data = dataset2019.iloc[1::2, :]

# Scale values for training
scaler = MinMaxScaler(feature_range=(0, 1))
training_data = pd.DataFrame(scaler.fit_transform(training_data_non_scaled),columns = dataset.columns)
validation_data = pd.DataFrame(scaler.transform(validation_data_non_scaled),columns = dataset.columns)

# %% [markdown]
# # Plotting
# Plotting raw data over a period, in addition to plotting air temperatures over water temperatures

# %%
# Plot all data over (about) three days
dataset_sample = dataset.iloc[:72]

sns.lineplot(x=dataset_sample.index, y="relative_humidity", data=dataset_sample);
#sns.lineplot(x=dataset_sample.index, y="rainfall", data=dataset_sample);
sns.lineplot(x=dataset_sample.index, y="wind_speed", data=dataset_sample);
#sns.lineplot(x=dataset_sample.index, y="wind_direction", data=dataset_sample);
#sns.lineplot(x=dataset_sample.index, y="tide_obs", data=dataset_sample);
#sns.lineplot(x=dataset_sample.index, y="tide_pred", data=dataset_sample);
sns.lineplot(x=dataset_sample.index, y="water_temperature", data=dataset_sample);
sns.lineplot(x=dataset_sample.index, y="air_temperature", data=dataset_sample);
sns.lineplot(x=dataset_sample.index, y="hour", data=dataset_sample);
sns.lineplot(x=dataset_sample.index, y="month", data=dataset_sample);

# %%
sns.lineplot(x=training_data.index, y="water_temperature", data=training_data);
sns.lineplot(x=training_data.index, y="air_temperature", data=training_data);

# %% [markdown]
# # Split data and convert to time series

# %%
trainx = training_data[hyperparams.features].values
trainy = training_data["water_temperature"].values

validx = validation_data[hyperparams.features].values
validy = validation_data["water_temperature"].values

train_time_plot = training_data.index.values
valid_time_plot = validation_data.index.values

# Convert using sliding window, like in https://datascience.stackexchange.com/questions/27533/keras-lstm-with-1d-time-series/27535#27535
def step_series(x, y, t, window_size, skip=1):
    x_stepped = np.empty((x.shape[0]-window_size*skip, window_size, x.shape[1]))
    y_stepped = np.empty(x.shape[0]-window_size*skip)
    t_stepped = np.empty(x.shape[0]-window_size*skip)
    for i in range(0, x.shape[0]-window_size*skip):
        for j in range(0, window_size):
            x_stepped[i,j,:] = x[i+j*skip]
        y_stepped[i] = y[i+window_size*skip]
        t_stepped[i] = t[i+window_size*skip]
    return x_stepped, y_stepped, t_stepped

trainx_stepped, trainy_stepped, train_time_plot_stepped = step_series(trainx, trainy, train_time_plot, hyperparams.look_back, hyperparams.look_back_skip)
validx_stepped, validy_stepped, valid_time_plot_stepped = step_series(validx, validy, valid_time_plot, hyperparams.look_back, hyperparams.look_back_skip)

# %% [markdown]
# # Build and train model

# %%
model = Sequential()
model.add(Conv1D(
    128, 
    kernel_size=3,
    strides=1, padding="causal",
    activation="swish",
    input_shape=(trainx_stepped.shape[1], trainx_stepped.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(Bidirectional(LSTM(64, activation="swish", return_sequences=True)))
model.add(Bidirectional(LSTM(64, activation="swish")))
model.add(Dense(1))
model.compile(
    loss=hyperparams.loss_function,
    optimizer=(hyperparams.optimizer(learning_rate=hyperparams.learning_rate) if hyperparams.learning_rate is not None else hyperparams.optimizer()),
    metrics=[RootMeanSquaredError()]
)
model.summary()

earlystopping = EarlyStopping(monitor ="val_loss", mode ="min", patience=hyperparams.earlystopping_patience, restore_best_weights = True) 

history = model.fit(
    trainx_stepped, 
    trainy_stepped, 
    epochs=hyperparams.num_of_epochs, 
    batch_size=hyperparams.batch_size, 
    callbacks=[earlystopping], 
    validation_data=(validx_stepped, validy_stepped), 
    shuffle=False
)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 18, 128)           2048
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 9, 128)            0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 9, 128)            98816
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 128)               98816
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 199,809
# Trainable params: 199,809
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 173/173 [==============================] - 22s 81ms/step - loss: 0.3138 - root_mean_squared_error: 0.5524 - val_loss: 0.1376 - val_root_mean_squared_error: 0.3710
# Epoch 2/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.1408 - root_mean_squared_error: 0.3690 - val_loss: 0.0730 - val_root_mean_squared_error: 0.2702
# Epoch 3/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0809 - root_mean_squared_error: 0.2793 - val_loss: 0.0507 - val_root_mean_squared_error: 0.2252
# Epoch 4/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0593 - root_mean_squared_error: 0.2393 - val_loss: 0.0428 - val_root_mean_squared_error: 0.2070
# Epoch 5/300
# 173/173 [==============================] - 14s 83ms/step - loss: 0.0515 - root_mean_squared_error: 0.2231 - val_loss: 0.0397 - val_root_mean_squared_error: 0.1993
# Epoch 6/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0484 - root_mean_squared_error: 0.2164 - val_loss: 0.0383 - val_root_mean_squared_error: 0.1956
# Epoch 7/300
# 173/173 [==============================] - 14s 83ms/step - loss: 0.0470 - root_mean_squared_error: 0.2133 - val_loss: 0.0374 - val_root_mean_squared_error: 0.1935
# Epoch 8/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0463 - root_mean_squared_error: 0.2116 - val_loss: 0.0369 - val_root_mean_squared_error: 0.1920
# Epoch 9/300
# 173/173 [==============================] - 14s 81ms/step - loss: 0.0458 - root_mean_squared_error: 0.2105 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1908
# Epoch 10/300
# 173/173 [==============================] - 14s 82ms/step - loss: 0.0454 - root_mean_squared_error: 0.2096 - val_loss: 0.0360 - val_root_mean_squared_error: 0.1898
# Epoch 11/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0450 - root_mean_squared_error: 0.2089 - val_loss: 0.0357 - val_root_mean_squared_error: 0.1890
# Epoch 12/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0447 - root_mean_squared_error: 0.2082 - val_loss: 0.0354 - val_root_mean_squared_error: 0.1881
# Epoch 13/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0444 - root_mean_squared_error: 0.2076 - val_loss: 0.0351 - val_root_mean_squared_error: 0.1874
# Epoch 14/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0442 - root_mean_squared_error: 0.2069 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1867
# Epoch 15/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0439 - root_mean_squared_error: 0.2063 - val_loss: 0.0346 - val_root_mean_squared_error: 0.1860
# Epoch 16/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0436 - root_mean_squared_error: 0.2057 - val_loss: 0.0343 - val_root_mean_squared_error: 0.1853
# Epoch 17/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0434 - root_mean_squared_error: 0.2051 - val_loss: 0.0341 - val_root_mean_squared_error: 0.1847
# Epoch 18/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0431 - root_mean_squared_error: 0.2045 - val_loss: 0.0339 - val_root_mean_squared_error: 0.1841
# Epoch 19/300
# 173/173 [==============================] - 14s 81ms/step - loss: 0.0428 - root_mean_squared_error: 0.2039 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1835
# Epoch 20/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0426 - root_mean_squared_error: 0.2033 - val_loss: 0.0334 - val_root_mean_squared_error: 0.1829
# Epoch 21/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0423 - root_mean_squared_error: 0.2026 - val_loss: 0.0332 - val_root_mean_squared_error: 0.1823
# Epoch 22/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0420 - root_mean_squared_error: 0.2020 - val_loss: 0.0330 - val_root_mean_squared_error: 0.1817
# Epoch 23/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0417 - root_mean_squared_error: 0.2013 - val_loss: 0.0328 - val_root_mean_squared_error: 0.1811
# Epoch 24/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0415 - root_mean_squared_error: 0.2006 - val_loss: 0.0326 - val_root_mean_squared_error: 0.1805
# Epoch 25/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0412 - root_mean_squared_error: 0.1999 - val_loss: 0.0324 - val_root_mean_squared_error: 0.1799
# Epoch 26/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0408 - root_mean_squared_error: 0.1991 - val_loss: 0.0321 - val_root_mean_squared_error: 0.1793
# Epoch 27/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0405 - root_mean_squared_error: 0.1984 - val_loss: 0.0319 - val_root_mean_squared_error: 0.1787
# Epoch 28/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0402 - root_mean_squared_error: 0.1976 - val_loss: 0.0317 - val_root_mean_squared_error: 0.1781
# Epoch 29/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0399 - root_mean_squared_error: 0.1967 - val_loss: 0.0315 - val_root_mean_squared_error: 0.1774
# Epoch 30/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0395 - root_mean_squared_error: 0.1958 - val_loss: 0.0312 - val_root_mean_squared_error: 0.1768
# Epoch 31/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0391 - root_mean_squared_error: 0.1949 - val_loss: 0.0310 - val_root_mean_squared_error: 0.1761
# Epoch 32/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0387 - root_mean_squared_error: 0.1939 - val_loss: 0.0308 - val_root_mean_squared_error: 0.1754
# Epoch 33/300
# 173/173 [==============================] - 14s 81ms/step - loss: 0.0383 - root_mean_squared_error: 0.1928 - val_loss: 0.0305 - val_root_mean_squared_error: 0.1747
# Epoch 34/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0379 - root_mean_squared_error: 0.1917 - val_loss: 0.0302 - val_root_mean_squared_error: 0.1739
# Epoch 35/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0374 - root_mean_squared_error: 0.1905 - val_loss: 0.0300 - val_root_mean_squared_error: 0.1731
# Epoch 36/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0369 - root_mean_squared_error: 0.1893 - val_loss: 0.0297 - val_root_mean_squared_error: 0.1723
# Epoch 37/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0364 - root_mean_squared_error: 0.1879 - val_loss: 0.0294 - val_root_mean_squared_error: 0.1715
# Epoch 38/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0358 - root_mean_squared_error: 0.1865 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1706
# Epoch 39/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0352 - root_mean_squared_error: 0.1849 - val_loss: 0.0288 - val_root_mean_squared_error: 0.1696
# Epoch 40/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0346 - root_mean_squared_error: 0.1832 - val_loss: 0.0284 - val_root_mean_squared_error: 0.1687
# Epoch 41/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0339 - root_mean_squared_error: 0.1814 - val_loss: 0.0281 - val_root_mean_squared_error: 0.1676
# Epoch 42/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0332 - root_mean_squared_error: 0.1795 - val_loss: 0.0277 - val_root_mean_squared_error: 0.1666
# Epoch 43/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0325 - root_mean_squared_error: 0.1774 - val_loss: 0.0274 - val_root_mean_squared_error: 0.1655
# Epoch 44/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0316 - root_mean_squared_error: 0.1751 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1643
# Epoch 45/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0308 - root_mean_squared_error: 0.1727 - val_loss: 0.0266 - val_root_mean_squared_error: 0.1631
# Epoch 46/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0298 - root_mean_squared_error: 0.1700 - val_loss: 0.0262 - val_root_mean_squared_error: 0.1618
# Epoch 47/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0289 - root_mean_squared_error: 0.1671 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1606
# Epoch 48/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0278 - root_mean_squared_error: 0.1640 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1593
# Epoch 49/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0267 - root_mean_squared_error: 0.1607 - val_loss: 0.0249 - val_root_mean_squared_error: 0.1579
# Epoch 50/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0256 - root_mean_squared_error: 0.1571 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1566
# Epoch 51/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0244 - root_mean_squared_error: 0.1533 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1552
# Epoch 52/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0231 - root_mean_squared_error: 0.1493 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1539
# Epoch 53/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0219 - root_mean_squared_error: 0.1452 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1525
# Epoch 54/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0206 - root_mean_squared_error: 0.1409 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1511
# Epoch 55/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0194 - root_mean_squared_error: 0.1367 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1496
# Epoch 56/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0183 - root_mean_squared_error: 0.1326 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1480
# Epoch 57/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0172 - root_mean_squared_error: 0.1288 - val_loss: 0.0214 - val_root_mean_squared_error: 0.1463
# Epoch 58/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0163 - root_mean_squared_error: 0.1253 - val_loss: 0.0209 - val_root_mean_squared_error: 0.1446
# Epoch 59/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0155 - root_mean_squared_error: 0.1224 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1428
# Epoch 60/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0149 - root_mean_squared_error: 0.1199 - val_loss: 0.0199 - val_root_mean_squared_error: 0.1409
# Epoch 61/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0144 - root_mean_squared_error: 0.1181 - val_loss: 0.0193 - val_root_mean_squared_error: 0.1391
# Epoch 62/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0140 - root_mean_squared_error: 0.1168 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1372
# Epoch 63/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0138 - root_mean_squared_error: 0.1159 - val_loss: 0.0184 - val_root_mean_squared_error: 0.1355
# Epoch 64/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0137 - root_mean_squared_error: 0.1155 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1339
# Epoch 65/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0136 - root_mean_squared_error: 0.1153 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1324
# Epoch 66/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0136 - root_mean_squared_error: 0.1154 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1310
# Epoch 67/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0137 - root_mean_squared_error: 0.1155 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1297
# Epoch 68/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0137 - root_mean_squared_error: 0.1157 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1285
# Epoch 69/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0138 - root_mean_squared_error: 0.1159 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1275
# Epoch 70/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0138 - root_mean_squared_error: 0.1161 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1266
# Epoch 71/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0139 - root_mean_squared_error: 0.1163 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1257
# Epoch 72/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0139 - root_mean_squared_error: 0.1164 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1249
# Epoch 73/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0139 - root_mean_squared_error: 0.1165 - val_loss: 0.0154 - val_root_mean_squared_error: 0.1242
# Epoch 74/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0139 - root_mean_squared_error: 0.1166 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1236
# Epoch 75/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0140 - root_mean_squared_error: 0.1166 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1230
# Epoch 76/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0140 - root_mean_squared_error: 0.1166 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1224
# Epoch 77/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0140 - root_mean_squared_error: 0.1166 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1219
# Epoch 78/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0140 - root_mean_squared_error: 0.1166 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1214
# Epoch 79/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0140 - root_mean_squared_error: 0.1166 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1210
# Epoch 80/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0139 - root_mean_squared_error: 0.1165 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1206
# Epoch 81/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0139 - root_mean_squared_error: 0.1165 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1202
# Epoch 82/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0139 - root_mean_squared_error: 0.1164 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1198
# Epoch 83/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0139 - root_mean_squared_error: 0.1163 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1195
# Epoch 84/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0139 - root_mean_squared_error: 0.1162 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1191
# Epoch 85/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0139 - root_mean_squared_error: 0.1161 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1188
# Epoch 86/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0138 - root_mean_squared_error: 0.1160 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1185
# Epoch 87/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0138 - root_mean_squared_error: 0.1159 - val_loss: 0.0140 - val_root_mean_squared_error: 0.1183
# Epoch 88/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0138 - root_mean_squared_error: 0.1158 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1180
# Epoch 89/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0138 - root_mean_squared_error: 0.1157 - val_loss: 0.0139 - val_root_mean_squared_error: 0.1178
# Epoch 90/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0137 - root_mean_squared_error: 0.1156 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1175
# Epoch 91/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0137 - root_mean_squared_error: 0.1155 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1173
# Epoch 92/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0137 - root_mean_squared_error: 0.1154 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1171
# Epoch 93/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0137 - root_mean_squared_error: 0.1153 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1169
# Epoch 94/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0136 - root_mean_squared_error: 0.1152 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1167
# Epoch 95/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0136 - root_mean_squared_error: 0.1151 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1165
# Epoch 96/300
# 173/173 [==============================] - 14s 81ms/step - loss: 0.0136 - root_mean_squared_error: 0.1149 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1163
# Epoch 97/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0135 - root_mean_squared_error: 0.1148 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1161
# Epoch 98/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0135 - root_mean_squared_error: 0.1147 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1159
# Epoch 99/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0135 - root_mean_squared_error: 0.1146 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1157
# Epoch 100/300
# 173/173 [==============================] - 14s 81ms/step - loss: 0.0135 - root_mean_squared_error: 0.1145 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1156
# Epoch 101/300
# 173/173 [==============================] - 14s 82ms/step - loss: 0.0134 - root_mean_squared_error: 0.1144 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1154
# Epoch 102/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0134 - root_mean_squared_error: 0.1143 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1153
# Epoch 103/300
# 173/173 [==============================] - 14s 83ms/step - loss: 0.0134 - root_mean_squared_error: 0.1141 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1151
# Epoch 104/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0134 - root_mean_squared_error: 0.1140 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1150
# Epoch 105/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0133 - root_mean_squared_error: 0.1139 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1148
# Epoch 106/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0133 - root_mean_squared_error: 0.1138 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1147
# Epoch 107/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0133 - root_mean_squared_error: 0.1137 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1145
# Epoch 108/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0133 - root_mean_squared_error: 0.1136 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1144
# Epoch 109/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0132 - root_mean_squared_error: 0.1135 - val_loss: 0.0131 - val_root_mean_squared_error: 0.1143
# Epoch 110/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0132 - root_mean_squared_error: 0.1134 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1141
# Epoch 111/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0132 - root_mean_squared_error: 0.1133 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1140
# Epoch 112/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0131 - root_mean_squared_error: 0.1132 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1139
# Epoch 113/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0131 - root_mean_squared_error: 0.1130 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1138
# Epoch 114/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0131 - root_mean_squared_error: 0.1129 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1136
# Epoch 115/300
# 173/173 [==============================] - 14s 83ms/step - loss: 0.0131 - root_mean_squared_error: 0.1128 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1135
# Epoch 116/300
# 173/173 [==============================] - 14s 82ms/step - loss: 0.0130 - root_mean_squared_error: 0.1127 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1134
# Epoch 117/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0130 - root_mean_squared_error: 0.1126 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1133
# Epoch 118/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0130 - root_mean_squared_error: 0.1125 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1132
# Epoch 119/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0130 - root_mean_squared_error: 0.1124 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1131
# Epoch 120/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0129 - root_mean_squared_error: 0.1123 - val_loss: 0.0128 - val_root_mean_squared_error: 0.1130
# Epoch 121/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0129 - root_mean_squared_error: 0.1122 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1129
# Epoch 122/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0129 - root_mean_squared_error: 0.1121 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1128
# Epoch 123/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0129 - root_mean_squared_error: 0.1120 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1127
# Epoch 124/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0129 - root_mean_squared_error: 0.1119 - val_loss: 0.0127 - val_root_mean_squared_error: 0.1126
# Epoch 125/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0128 - root_mean_squared_error: 0.1118 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1125
# Epoch 126/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0128 - root_mean_squared_error: 0.1117 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1124
# Epoch 127/300
# 173/173 [==============================] - 14s 81ms/step - loss: 0.0128 - root_mean_squared_error: 0.1116 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1123
# Epoch 128/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0128 - root_mean_squared_error: 0.1115 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1122
# Epoch 129/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0127 - root_mean_squared_error: 0.1114 - val_loss: 0.0126 - val_root_mean_squared_error: 0.1121
# Epoch 130/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0127 - root_mean_squared_error: 0.1113 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1120
# Epoch 131/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0127 - root_mean_squared_error: 0.1112 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1119
# Epoch 132/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0127 - root_mean_squared_error: 0.1111 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1118
# Epoch 133/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0126 - root_mean_squared_error: 0.1110 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1117
# Epoch 134/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0126 - root_mean_squared_error: 0.1109 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1116
# Epoch 135/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0126 - root_mean_squared_error: 0.1108 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1115
# Epoch 136/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0126 - root_mean_squared_error: 0.1108 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1115
# Epoch 137/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0126 - root_mean_squared_error: 0.1107 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1114
# Epoch 138/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0125 - root_mean_squared_error: 0.1106 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1113
# Epoch 139/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0125 - root_mean_squared_error: 0.1105 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
# Epoch 140/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0125 - root_mean_squared_error: 0.1104 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1111
# Epoch 141/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0125 - root_mean_squared_error: 0.1103 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110
# Epoch 142/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0125 - root_mean_squared_error: 0.1102 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1110
# Epoch 143/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0124 - root_mean_squared_error: 0.1101 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1109
# Epoch 144/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0124 - root_mean_squared_error: 0.1100 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1108
# Epoch 145/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0124 - root_mean_squared_error: 0.1100 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1107
# Epoch 146/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0124 - root_mean_squared_error: 0.1099 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1107
# Epoch 147/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0124 - root_mean_squared_error: 0.1098 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1106
# Epoch 148/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0123 - root_mean_squared_error: 0.1097 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1105
# Epoch 149/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0123 - root_mean_squared_error: 0.1096 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1104
# Epoch 150/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0123 - root_mean_squared_error: 0.1095 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1104
# Epoch 151/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0123 - root_mean_squared_error: 0.1095 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1103
# Epoch 152/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0123 - root_mean_squared_error: 0.1094 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1102
# Epoch 153/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0122 - root_mean_squared_error: 0.1093 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1101
# Epoch 154/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0122 - root_mean_squared_error: 0.1092 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1101
# Epoch 155/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0122 - root_mean_squared_error: 0.1091 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1100
# Epoch 156/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0122 - root_mean_squared_error: 0.1090 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1099
# Epoch 157/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0122 - root_mean_squared_error: 0.1090 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1099
# Epoch 158/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0122 - root_mean_squared_error: 0.1089 - val_loss: 0.0121 - val_root_mean_squared_error: 0.1098
# Epoch 159/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0121 - root_mean_squared_error: 0.1088 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1097
# Epoch 160/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0121 - root_mean_squared_error: 0.1087 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1097
# Epoch 161/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0121 - root_mean_squared_error: 0.1086 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1096
# Epoch 162/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0121 - root_mean_squared_error: 0.1086 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1095
# Epoch 163/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0121 - root_mean_squared_error: 0.1085 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1095
# Epoch 164/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0120 - root_mean_squared_error: 0.1084 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1094
# Epoch 165/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0120 - root_mean_squared_error: 0.1083 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1093
# Epoch 166/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0120 - root_mean_squared_error: 0.1083 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1093
# Epoch 167/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0120 - root_mean_squared_error: 0.1082 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1092
# Epoch 168/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0120 - root_mean_squared_error: 0.1081 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1092
# Epoch 169/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0120 - root_mean_squared_error: 0.1080 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1091
# Epoch 170/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0119 - root_mean_squared_error: 0.1080 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1090
# Epoch 171/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0119 - root_mean_squared_error: 0.1079 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1090
# Epoch 172/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0119 - root_mean_squared_error: 0.1078 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1089
# Epoch 173/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0119 - root_mean_squared_error: 0.1077 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1089
# Epoch 174/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0119 - root_mean_squared_error: 0.1077 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1088
# Epoch 175/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0119 - root_mean_squared_error: 0.1076 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1087
# Epoch 176/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0118 - root_mean_squared_error: 0.1075 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1087
# Epoch 177/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0118 - root_mean_squared_error: 0.1075 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1086
# Epoch 178/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0118 - root_mean_squared_error: 0.1074 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1086
# Epoch 179/300
# 173/173 [==============================] - 14s 83ms/step - loss: 0.0118 - root_mean_squared_error: 0.1073 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1085
# Epoch 180/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0118 - root_mean_squared_error: 0.1073 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1085
# Epoch 181/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0118 - root_mean_squared_error: 0.1072 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1084
# Epoch 182/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0117 - root_mean_squared_error: 0.1071 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1084
# Epoch 183/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0117 - root_mean_squared_error: 0.1070 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1083
# Epoch 184/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0117 - root_mean_squared_error: 0.1070 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 185/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0117 - root_mean_squared_error: 0.1069 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1082
# Epoch 186/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0117 - root_mean_squared_error: 0.1068 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1081
# Epoch 187/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0117 - root_mean_squared_error: 0.1068 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1081
# Epoch 188/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0117 - root_mean_squared_error: 0.1067 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 189/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0116 - root_mean_squared_error: 0.1066 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1080
# Epoch 190/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0116 - root_mean_squared_error: 0.1066 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1079
# Epoch 191/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0116 - root_mean_squared_error: 0.1065 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1079
# Epoch 192/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0116 - root_mean_squared_error: 0.1064 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1078
# Epoch 193/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0116 - root_mean_squared_error: 0.1064 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1078
# Epoch 194/300
# 173/173 [==============================] - 13s 73ms/step - loss: 0.0116 - root_mean_squared_error: 0.1063 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1077
# Epoch 195/300
# 173/173 [==============================] - 14s 81ms/step - loss: 0.0116 - root_mean_squared_error: 0.1062 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1077
# Epoch 196/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0115 - root_mean_squared_error: 0.1062 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1076
# Epoch 197/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0115 - root_mean_squared_error: 0.1061 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1076
# Epoch 198/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0115 - root_mean_squared_error: 0.1061 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1075
# Epoch 199/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0115 - root_mean_squared_error: 0.1060 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1075
# Epoch 200/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0115 - root_mean_squared_error: 0.1059 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1074
# Epoch 201/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0115 - root_mean_squared_error: 0.1059 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1074
# Epoch 202/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0115 - root_mean_squared_error: 0.1058 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1073
# Epoch 203/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0114 - root_mean_squared_error: 0.1057 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1073
# Epoch 204/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0114 - root_mean_squared_error: 0.1057 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1073
# Epoch 205/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0114 - root_mean_squared_error: 0.1056 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1072
# Epoch 206/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0114 - root_mean_squared_error: 0.1056 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1072
# Epoch 207/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0114 - root_mean_squared_error: 0.1055 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1071
# Epoch 208/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0114 - root_mean_squared_error: 0.1054 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1071
# Epoch 209/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0114 - root_mean_squared_error: 0.1054 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1070
# Epoch 210/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0113 - root_mean_squared_error: 0.1053 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1070
# Epoch 211/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0113 - root_mean_squared_error: 0.1053 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1069
# Epoch 212/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0113 - root_mean_squared_error: 0.1052 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1069
# Epoch 213/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0113 - root_mean_squared_error: 0.1051 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1068
# Epoch 214/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0113 - root_mean_squared_error: 0.1051 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1068
# Epoch 215/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0113 - root_mean_squared_error: 0.1050 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1068
# Epoch 216/300
# 173/173 [==============================] - 13s 73ms/step - loss: 0.0113 - root_mean_squared_error: 0.1050 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 217/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0113 - root_mean_squared_error: 0.1049 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1067
# Epoch 218/300
# 173/173 [==============================] - 14s 82ms/step - loss: 0.0112 - root_mean_squared_error: 0.1048 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 219/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0112 - root_mean_squared_error: 0.1048 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 220/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0112 - root_mean_squared_error: 0.1047 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1066
# Epoch 221/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0112 - root_mean_squared_error: 0.1047 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1065
# Epoch 222/300
# 173/173 [==============================] - 13s 73ms/step - loss: 0.0112 - root_mean_squared_error: 0.1046 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1065
# Epoch 223/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0112 - root_mean_squared_error: 0.1046 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1064
# Epoch 224/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0112 - root_mean_squared_error: 0.1045 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1064
# Epoch 225/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0112 - root_mean_squared_error: 0.1044 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1063
# Epoch 226/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0111 - root_mean_squared_error: 0.1044 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1063
# Epoch 227/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0111 - root_mean_squared_error: 0.1043 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1063
# Epoch 228/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0111 - root_mean_squared_error: 0.1043 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1062
# Epoch 229/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0111 - root_mean_squared_error: 0.1042 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1062
# Epoch 230/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0111 - root_mean_squared_error: 0.1042 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1061
# Epoch 231/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0111 - root_mean_squared_error: 0.1041 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1061
# Epoch 232/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0111 - root_mean_squared_error: 0.1041 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1061
# Epoch 233/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0111 - root_mean_squared_error: 0.1040 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1060
# Epoch 234/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0110 - root_mean_squared_error: 0.1040 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1060
# Epoch 235/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0110 - root_mean_squared_error: 0.1039 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1060
# Epoch 236/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0110 - root_mean_squared_error: 0.1038 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1059
# Epoch 237/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0110 - root_mean_squared_error: 0.1038 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1059
# Epoch 238/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0110 - root_mean_squared_error: 0.1037 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1058
# Epoch 239/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0110 - root_mean_squared_error: 0.1037 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1058
# Epoch 240/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0110 - root_mean_squared_error: 0.1036 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1058
# Epoch 241/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0110 - root_mean_squared_error: 0.1036 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1057
# Epoch 242/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0110 - root_mean_squared_error: 0.1035 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1057
# Epoch 243/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0109 - root_mean_squared_error: 0.1035 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1057
# Epoch 244/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0109 - root_mean_squared_error: 0.1034 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1056
# Epoch 245/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0109 - root_mean_squared_error: 0.1034 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1056
# Epoch 246/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0109 - root_mean_squared_error: 0.1033 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1056
# Epoch 247/300
# 173/173 [==============================] - 14s 80ms/step - loss: 0.0109 - root_mean_squared_error: 0.1033 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1055
# Epoch 248/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0109 - root_mean_squared_error: 0.1032 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1055
# Epoch 249/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0109 - root_mean_squared_error: 0.1032 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1055
# Epoch 250/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0109 - root_mean_squared_error: 0.1031 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1054
# Epoch 251/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0109 - root_mean_squared_error: 0.1031 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1054
# Epoch 252/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0108 - root_mean_squared_error: 0.1030 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1054
# Epoch 253/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0108 - root_mean_squared_error: 0.1030 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1053
# Epoch 254/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0108 - root_mean_squared_error: 0.1029 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1053
# Epoch 255/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0108 - root_mean_squared_error: 0.1029 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1053
# Epoch 256/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0108 - root_mean_squared_error: 0.1028 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1052
# Epoch 257/300
# 173/173 [==============================] - 14s 79ms/step - loss: 0.0108 - root_mean_squared_error: 0.1028 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1052
# Epoch 258/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0108 - root_mean_squared_error: 0.1027 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1052
# Epoch 259/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0108 - root_mean_squared_error: 0.1027 - val_loss: 0.0111 - val_root_mean_squared_error: 0.1051
# Epoch 260/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0108 - root_mean_squared_error: 0.1026 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1051
# Epoch 261/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0107 - root_mean_squared_error: 0.1026 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1051
# Epoch 262/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0107 - root_mean_squared_error: 0.1025 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1050
# Epoch 263/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0107 - root_mean_squared_error: 0.1025 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1050
# Epoch 264/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0107 - root_mean_squared_error: 0.1024 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1050
# Epoch 265/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0107 - root_mean_squared_error: 0.1024 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1049
# Epoch 266/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0107 - root_mean_squared_error: 0.1023 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1049
# Epoch 267/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0107 - root_mean_squared_error: 0.1023 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1049
# Epoch 268/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0107 - root_mean_squared_error: 0.1022 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 269/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0107 - root_mean_squared_error: 0.1022 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 270/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0107 - root_mean_squared_error: 0.1021 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1048
# Epoch 271/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0106 - root_mean_squared_error: 0.1021 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 272/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0106 - root_mean_squared_error: 0.1021 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 273/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0106 - root_mean_squared_error: 0.1020 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 274/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0106 - root_mean_squared_error: 0.1020 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1047
# Epoch 275/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0106 - root_mean_squared_error: 0.1019 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 276/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0106 - root_mean_squared_error: 0.1019 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 277/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0106 - root_mean_squared_error: 0.1018 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1046
# Epoch 278/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0106 - root_mean_squared_error: 0.1018 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1045
# Epoch 279/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0106 - root_mean_squared_error: 0.1017 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1045
# Epoch 280/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0106 - root_mean_squared_error: 0.1017 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1045
# Epoch 281/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0105 - root_mean_squared_error: 0.1016 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1044
# Epoch 282/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0105 - root_mean_squared_error: 0.1016 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1044
# Epoch 283/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0105 - root_mean_squared_error: 0.1016 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1044
# Epoch 284/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0105 - root_mean_squared_error: 0.1015 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1044
# Epoch 285/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0105 - root_mean_squared_error: 0.1015 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043
# Epoch 286/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0105 - root_mean_squared_error: 0.1014 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043
# Epoch 287/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0105 - root_mean_squared_error: 0.1014 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043
# Epoch 288/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0105 - root_mean_squared_error: 0.1013 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043
# Epoch 289/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0105 - root_mean_squared_error: 0.1013 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 290/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0105 - root_mean_squared_error: 0.1013 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 291/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0105 - root_mean_squared_error: 0.1012 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1042
# Epoch 292/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0104 - root_mean_squared_error: 0.1012 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1041
# Epoch 293/300
# 173/173 [==============================] - 14s 81ms/step - loss: 0.0104 - root_mean_squared_error: 0.1011 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1041
# Epoch 294/300
# 173/173 [==============================] - 13s 77ms/step - loss: 0.0104 - root_mean_squared_error: 0.1011 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1041
# Epoch 295/300
# 173/173 [==============================] - 13s 75ms/step - loss: 0.0104 - root_mean_squared_error: 0.1010 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1041
# Epoch 296/300
# 173/173 [==============================] - 14s 78ms/step - loss: 0.0104 - root_mean_squared_error: 0.1010 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1040
# Epoch 297/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0104 - root_mean_squared_error: 0.1010 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1040
# Epoch 298/300
# 173/173 [==============================] - 13s 78ms/step - loss: 0.0104 - root_mean_squared_error: 0.1009 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1040
# Epoch 299/300
# 173/173 [==============================] - 13s 74ms/step - loss: 0.0104 - root_mean_squared_error: 0.1009 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1040
# Epoch 300/300
# 173/173 [==============================] - 13s 76ms/step - loss: 0.0104 - root_mean_squared_error: 0.1008 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1039

# %% [markdown]
# # Plot training and validation loss

# %%
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="validation loss")
plt.legend()
plt.show()

# %% [markdown]
# # Visualize and compare predictions

# %%
predy_stepped = model.predict(validx_stepped[::2, :, :])

predict_matrix = np.zeros(shape=(len(predy_stepped), 14))
predict_matrix[:,0] = predy_stepped[:,0]
predy_stepped = scaler.inverse_transform(predict_matrix)

valid_matrix = np.zeros(shape=(len(validy_stepped), 14))
valid_matrix[:,0] = validy_stepped
validy_stepped2 = scaler.inverse_transform(valid_matrix)
     
plt.plot(validation_data_non_scaled.index[36:], validy_stepped2[:, 0], label="Reelle målinger", color="lightskyblue")
plt.plot(validation_data_non_scaled.index[36::2], predy_stepped[:, 0], label="Predikerte verdier", color="red")
plt.legend()
plt.show()

# %%
model.save("output/model")
